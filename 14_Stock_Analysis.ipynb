# %% [markdown]
# <a href="https://colab.research.google.com/github/om123-collab/playground-f4tod5ym/blob/master/14_Stock_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

def calculate_sma(data, window_size):
  """Calculates the Simple Moving Average (SMA)."""
  sma = data.rolling(window=window_size).mean()
  return sma

def plot_stock_data(data, sma):
  """Plots the stock price and the SMA."""
  plt.figure(figsize=(12, 6))
  plt.plot(data, label='Stock Price')
  plt.plot(sma, label=f'SMA ({window_size})')
  plt.xlabel('Time')
  plt.ylabel('Price')
  plt.title('Stock Price with Simple Moving Average')
  plt.legend()
  plt.show()

# Example Usage (Replace with actual stock price data)
if __name__ == "__main__":
  # Sample data (replace with actual stock price data)
  # Assuming 'data' is a pandas Series with dates as index and prices as values
  data = pd.Series([10, 12, 15, 13, 18, 20, 17, 22, 25, 24],
                  index=pd.date_range('2024-01-01', periods=10))

  window_size = 3  # Calculate SMA over 3 days
  sma = calculate_sma(data, window_size)

  plot_stock_data(data, sma)
