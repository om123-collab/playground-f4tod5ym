# %% [markdown]
# <a href="https://colab.research.google.com/github/om123-collab/playground-f4tod5ym/blob/master/13_Simple_Linear_Regression_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data (replace with your actual data)
x = np.random.rand(100) * 10
y = 2 * x + 5 + np.random.randn(100) * 2

# Calculate linear regression coefficients
slope, intercept = np.polyfit(x, y, 1)

# Create a scatter plot
plt.scatter(x, y, label='Data Points')

# Plot the regression line
plt.plot(x, slope * x + intercept, color='red', label='Regression Line')

# Add labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()

plt.show()
